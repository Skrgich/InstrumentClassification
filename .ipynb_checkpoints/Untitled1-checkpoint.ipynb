# %%
import numpy as np
import librosa.display, os
import matplotlib.pyplot as plt
# %matplotlib inline

def create_spectrogram(audio_file, image_file):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1)

    y, sr = librosa.load(audio_file)
    ms = librosa.feature.melspectrogram(signal = y, sr = sr)
    log_ms = librosa.power_to_db(ms, ref=np.max)
    librosa.display.specshow(log_ms, sr=sr)

    fig.savefig(image_file)
    plt.close(fig)
    
def create_pngs_from_wavs(input_path, output_path):
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    dir = os.listdir(input_path)

    for i, file in enumerate(dir):
        input_file = os.path.join(input_path, file)
        output_file = os.path.join(output_path, file.replace('.wav', '.png'))
        create_spectrogram(input_file, output_file)

# %%
create_pngs_from_wavs('Dataset/IRMAS_Training_Data/cel', 'Spectrograms/cel')
# Out:
# ---------------------------------------------------------------------------
# ParameterError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 create_pngs_from_wavs('Dataset/IRMAS_Training_Data/cel', 'Spectrograms/cel')
#
# Cell In[4], line 28, in create_pngs_from_wavs(input_path, output_path)
#      26 input_file = os.path.join(input_path, file)
#      27 output_file = os.path.join(output_path, file.replace('.wav', '.png'))
# ---> 28 create_spectrogram(input_file, output_file)
#
# Cell In[4], line 12, in create_spectrogram(audio_file, image_file)
#       9 fig.subplots_adjust(left=0, right=1, bottom=0, top=1)
#      11 y, sr = librosa.load(audio_file)
# ---> 12 ms = librosa.feature.melspectrogram(signal = y, sr = sr)
#      13 log_ms = librosa.power_to_db(ms, ref=np.max)
#      14 librosa.display.specshow(log_ms, sr=sr)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\librosa\util\decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\librosa\feature\spectral.py:2043, in melspectrogram(y, sr, S, n_fft, hop_length, win_length, window, center, pad_mode, power, **kwargs)
#    1922 @deprecate_positional_args
#    1923 def melspectrogram(
#    1924     *,
#    (...)
#    1935     **kwargs,
#    1936 ):
#    1937     """Compute a mel-scaled spectrogram.
#    1938
#    1939     If a spectrogram input ``S`` is provided, then it is mapped directly onto
#    (...)
#    2040     >>> ax.set(title='Mel-frequency spectrogram')
#    2041     """
# -> 2043     S, n_fft = _spectrogram(
#    2044         y=y,
#    2045         S=S,
#    2046         n_fft=n_fft,
#    2047         hop_length=hop_length,
#    2048         power=power,
#    2049         win_length=win_length,
#    2050         window=window,
#    2051         center=center,
#    2052         pad_mode=pad_mode,
#    2053     )
#    2055     # Build a Mel filter
#    2056     mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\librosa\core\spectrum.py:2564, in _spectrogram(y, S, n_fft, hop_length, power, win_length, window, center, pad_mode)
#    2559         n_fft = 2 * (S.shape[-2] - 1)
#    2560 else:
#    2561     # Otherwise, compute a magnitude spectrogram from input
#    2562     S = (
#    2563         np.abs(
# -> 2564             stft(
#    2565                 y,
#    2566                 n_fft=n_fft,
#    2567                 hop_length=hop_length,
#    2568                 win_length=win_length,
#    2569                 center=center,
#    2570                 window=window,
#    2571                 pad_mode=pad_mode,
#    2572             )
#    2573         )
#    2574         ** power
#    2575     )
#    2577 return S, n_fft
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\librosa\util\decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\librosa\core\spectrum.py:202, in stft(y, n_fft, hop_length, win_length, window, center, dtype, pad_mode)
#     199     hop_length = int(win_length // 4)
#     201 # Check audio is valid
# --> 202 util.valid_audio(y, mono=False)
#     204 fft_window = get_window(window, win_length, fftbins=True)
#     206 # Pad the window out to n_fft size
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\librosa\util\decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\librosa\util\utils.py:272, in valid_audio(y, mono)
#     216 """Determine whether a variable contains valid audio data.
#     217
#     218 The following conditions must be satisfied:
#    (...)
#     268 numpy.float32
#     269 """
#     271 if not isinstance(y, np.ndarray):
# --> 272     raise ParameterError("Audio data must be of type numpy.ndarray")
#     274 if not np.issubdtype(y.dtype, np.floating):
#     275     raise ParameterError("Audio data must be floating-point")
#
# ParameterError: Audio data must be of type numpy.ndarray
